# %% [markdown]
# ### Importing the library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading the Data set

# %%
df = pd.read_csv('Student_performance_data _.csv')
df
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %% [markdown]
# ### Statical Analysis

# %%
df.describe()
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# ...

# %%
# Correlation Matrix
correlation_matrix = df.corr()
print(correlation_matrix)
# Out:
#                    StudentID       Age    Gender  Ethnicity  \
# StudentID           1.000000 -0.042255 -0.014625  -0.012990
# Age                -0.042255  1.000000  0.044895  -0.028473
# Gender             -0.014625  0.044895  1.000000   0.016010
# Ethnicity          -0.012990 -0.028473  0.016010   1.000000
# ParentalEducation  -0.002307  0.025099  0.006771   0.033595
# StudyTimeWeekly     0.026976 -0.006800  0.011469   0.007184
# Absences            0.014841 -0.011511  0.021479  -0.025712
# Tutoring           -0.007834 -0.012076 -0.031597  -0.017440
# ParentalSupport     0.003016  0.033197  0.008065   0.020922
# Extracurricular    -0.003611 -0.025061 -0.005964  -0.008927
# Sports             -0.020703 -0.046320 -0.008897  -0.004484
# Music              -0.005468 -0.003492  0.007109  -0.014627
# Volunteering        0.008011  0.013074 -0.000200   0.013468
# GPA                -0.002697  0.000275 -0.013360   0.027760
# GradeClass         -0.098500 -0.006250  0.022998  -0.023326
#
# ...

# %%
# Seting the style of plots
sns.set(style='whitegrid')

#plotting distribution of key variable
plt.figure(figsize=(20,12))

# %%
#Distribution of age
plt.subplot(2,2,1)
sns.histplot(df['Age'])
plt.title('Age Distribution')
plt.show()

# %%
#Distribution of Study time weekly
plt.subplot(2,3,2)
sns.histplot(df['StudyTimeWeekly'], kde=True)
plt.title('Study Time Weekly Distribution')
plt.show()

# %%
# Distribution of GPA
plt.subplot(2, 3, 3)
sns.histplot(df['GPA'], kde= True)
plt.title("GPA Distribution")
plt.show()

# %%
# Distribution of Abesence 
plt.subplot(2,3,4)
sns.histplot(df['Absences'], kde=True)
plt.title('Abesence Distribution')
plt.show()

# %%
# Distribution of Parental Support
plt.subplot(2,3,5)
sns.histplot(df['ParentalSupport'], kde=True)
plt.title('Parental Support Distribution')
plt.show()

# %%
# Distribution of Grade Class
plt.subplot(2, 3, 6)
sns.histplot(df['GradeClass'], kde=True)
plt.title('Grade Class Distribution')
plt.show()

# %% [markdown]
# ### Correlation Heatmap

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# ### Scatter plot to explore relationship

# %%
plt.figure(figsize=(18,10))

# %%
# GPA vs Study Time Weekly
plt.subplot(2,1,1)
sns.scatterplot(x='StudyTimeWeekly', y='GPA', data=df)
plt.title('GPA vs Study Time Weekly')
plt.show()

# %%
# GPA vs Absences
plt.subplot(2,1,2)
sns.scatterplot(x='Absences', y='GPA', data=df)
plt.title("GPA vs Absences")
plt.show()

# %%
# GPA vs Parental Support
plt.subplot(2,2,3)
sns.scatterplot(x='ParentalSupport', y='GPA', data=df)
plt.title('GPA vs Parental Support')
plt.show()

# %%
# GPA vs Grade Class
plt.subplot(2,2,4)
sns.scatterplot(x='GradeClass', y='GPA', data=df)
plt.title('GPA vs Grade Class')
plt.show()

# %% [markdown]
# ### Box plots to compare distributions across categories

# %%
plt.figure(figsize=(18,10))

# %%
#GPA by Gender
plt.subplot(2,2,1)
sns.boxplot(x='Gender', y='GPA', data=df)
plt.title('GPA by Gender')
plt.show()

# %%
# GPA by Tutoring
plt.subplot(2,2,2)
sns.boxplot(x='Tutoring', y='GPA', data=df)
plt.title('GPA by Tutoring')
plt.show()

# %%
# GPA by Extracurricular
plt.subplot(2,2,3)
sns.boxplot(x='Extracurricular', y='GPA', data=df)
plt.title('GPA by Extracurricular')
plt.show()

# %%
# Gpa by Volunteering
plt.subplot(2,2,4)
sns.boxplot(x='Volunteering', y='GPA', data=df)
plt.title('GPA by Volunteering')
plt.show()

# %% [markdown]
# ### Pair Plot

# %% [markdown]
# #### It will show the relationshop between pairs of variable

# %%
sns.pairplot(df[['GPA', 'Absences', 'StudyTimeWeekly', 'ParentalSupport', 'Gender']], hue='Gender', palette='coolwarm')
plt.suptitle('Pair Plot of key variable', y=1.02)
plt.show()

# %% [markdown]
# ### Facet Grid

# %% [markdown]
# #### Facet Grid to show GPA distribution across different levels of parental support and gender

# %%
g= sns.FacetGrid(df, row='ParentalSupport', col='Gender', margin_titles=True, height=3, aspect=1.5)
g.map(sns.histplot, 'GPA')
g.add_legend()
plt.suptitle('GPA Distribution by Parental Support and Gender', y=1.02)
plt.show()

# %% [markdown]
# ### 3D Scatter Plot

# %% [markdown]
# #### 3D Scatter plot with GPA, StudyTimeWeekly, and Absences

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(df['StudyTimeWeekly'], df['Absences'], df['GPA'], c=df['GPA'], cmap='viridis', marker='o')

ax.set_xlabel('Study Time Weekly')
ax.set_ylabel('Absences')
ax.set_zlabel('GPA')
plt.title('3D Scatter Plot of GPA, Study Time Weekly, and Absences')
plt.colorbar(sc, ax=ax, label='GPA')
plt.show()
